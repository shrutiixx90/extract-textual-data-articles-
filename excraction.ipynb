# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import re
import os

# Function to extract article title and text from URL
def extract_article(url):
    try:
        response = requests.get(url)
        soup = BeautifulSoup(response.content, 'html.parser')
        
        title = soup.find('title').text.strip()
        
        # Extract article text
        article_text = ''
        for paragraph in soup.find_all('p'):
            article_text += paragraph.get_text() + '\n'
        
        return title, article_text
    except Exception as e:
        print(f"Error extracting article from {url}: {str(e)}")
        return None, None

# Read URLs from the provided Excel file
input_file = "C:\\Users\\dell\\Downloads\\Input.xlsx"
df = pd.read_excel(input_file)

# Create a directory to save the extracted text files
output_directory = "extracted_articles"
os.makedirs(output_directory, exist_ok=True)

# Extract articles and save them as text files
for index, row in df.iterrows():
    url_id = row['URL_ID']
    url = row['URL']
    title, article_text = extract_article(url)
    if title and article_text:
        # Remove special characters from title to create a valid filename
        title = re.sub(r'[^\w\s]', '', title)
        # Create a text file with the URL_ID as the filename
        filename = os.path.join(output_directory, f"{url_id}_{title}.txt")
        # Write article title and text to the text file
        with open(filename, 'w', encoding='utf-8') as file:
            file.write(title + '\n\n')
            file.write(article_text)
        print(f"Article extracted and saved: {filename}")
    else:
        print(f"Failed to extract article from URL: {url}")

print("Extraction complete.")
# Out:
# Article extracted and saved: extracted_articles\blackassign0001_Rising IT cities and its impact on the economy environment infrastructure and city life by the year 2040  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0002_Rising IT Cities and Their Impact on the Economy Environment Infrastructure and City Life in Future  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0003_Internet Demands Evolution Communication Impact and 2035s Alternative Pathways  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0004_Rise of Cybercrime and its Effect in upcoming Future  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0005_OTT platform and its impact on the entertainment industry in Future  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0006_The rise of the OTT platform and its impact on the entertainment industry by 2040  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0007_Rise of Cyber Crime and its Effects  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0008_Rise of Internet Demand and Its Impact on Communications and Alternatives by the Year 2035  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0009_Rise of Cybercrime and its Effect by the Year 2040  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0010_Rise of Cybercrime and its Effect by the Year 2040  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0011_Rise of Internet Demand and its Impact on Communications and Alternatives by the Year 2035  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0012_Rise of telemedicine and its Impact on Livelihood by 2040  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0013_Rise of ehealth and its impact on humans by the year 2030  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0014_Rise of ehealth and its impact on humans by the year 2030  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0015_Rise of telemedicine and its Impact on Livelihood by 2040  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0016_Rise of telemedicine and its Impact on Livelihood by 2040  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0017_Rise of Chatbots and its impact on customer support by the year 2040  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0018_Rise of ehealth and its impact on humans by the year 2030  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0019_How does marketing influence businesses and consumers  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0020_How advertisement increase your market value  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0021_Negative effects of marketing on society  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0022_How advertisementmarketing affects business  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0023_Rising IT cities will impact the economy environment infrastructure and city life by the year 2035  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0024_Rise of OTT platform and its impact on entertainment industry by the year 2030  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0025_Rise of Electric Vehicles and its Impact on Livelihood by 2040  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0026_Rise of electric vehicle and its impact on livelihood by the year 2040  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0027_Oil prices by the year 2040 and how it will impact the world economy  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0028_An outlook of healthcare by the year 2040 and how it will impact human lives  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0029_AI in healthcare to Improve Patient Outcomes  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0030_What if the Creation is Taking Over the Creator  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0031_What Jobs Will Robots Take From Humans in The Future  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0032_Will Machine Replace The Human in the Future of Work  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0033_Will AI Replace Us or Work With Us  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0034_Will machine replace the human in the future of work  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0035_How humans and machines are evolving to work together  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0036_Page not found  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0037_How machine learning will affect your business  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0038_Deep learning impact on areas of elearning  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0039_How to protect future data and its privacy  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0040_How Machines AI Automations and Robohuman are Effective in Finance and Banking  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0041_How Robo Human will Impact the Future  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0042_How AI will change the World  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0043_Future of Work How AI Has Entered the Workplace  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0044_How machine learning used in finance and banking  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0045_How AI will impact the future of work  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0046_All you need to know about online marketing  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0047_Evolution of Advertising Industry  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0048_How Data Analytics can help your business respond to the impact of COVID19  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0049_Page not found  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0050_Environmental impact of the COVID19 pandemic  Lesson for the Future  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0051_How Data Analytics and AI are used to halt the COVID19 Pandemic  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0052_AI Machine Learning Statistics and Data Mining  what is the difference.txt
# Article extracted and saved: extracted_articles\blackassign0053_Python became the choice for Data Science  how  lets know.txt
# Article extracted and saved: extracted_articles\blackassign0054_Google fit measure heart and respiratory rates using phone how.txt
# Article extracted and saved: extracted_articles\blackassign0055_mobile apps  Future  blackcoffer insights  know more about unknow facts.txt
# Article extracted and saved: extracted_articles\blackassign0056_AI in health and medicine  impact of AI  blackcoffer insights.txt
# Article extracted and saved: extracted_articles\blackassign0057_telemedicine  What patients like and dislike about it  blackcoffer insights.txt
# Article extracted and saved: extracted_articles\blackassign0058_forecast future technologies how to  blackcoffer insights.txt
# Article extracted and saved: extracted_articles\blackassign0059_Can robots tackle life loneliness  blackcoffer insights.txt
# Article extracted and saved: extracted_articles\blackassign0060_Sociotechnical considerations  Embedding care robots into society.txt
# Article extracted and saved: extracted_articles\blackassign0061_future digitalization of healthcare services  management challenges.txt
# Article extracted and saved: extracted_articles\blackassign0062_Are we any closer to preventing a nuclear holocaust  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0063_Will technology eliminate the need for animal testing in drug development  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0064_Will we ever understand the nature of consciousness  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0065_Will we ever colonize outer space  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0066_What is the chance Homo sapiens will survive for the next 500 years  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0067_Why does your business need a chatbot  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0068_How you lead a project or a team without any technical expertise  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0069_Can You Be Great Leader Without Technical Expertise  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0070_How does artificial intelligence affect the environment  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0071_How to Overcome Your Fear of Making Mistakes  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0072_Is Perfection the Greatest enemy of Productivity  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0073_Global financial crisis 2008 causeseffects and its solution  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0074_Gender diversity and Equality in the tech industry  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0075_How to overcome your fear of making mistakes  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0076_How Small Business can survive the Coronavirus Crisis  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0077_Impacts of COVID 19 on Food products  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0078_Impacts of COVID 19 on Vegetable Vendors  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0079_Impact of COVID19 pandemic on Tourism  Aviation industries  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0080_Impact of COVID19 pandemic on sports events around the world  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0081_Changing landscape and emerging trends in the Indian ITITeS Industry  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0082_Online gaming Adolescent online gaming effects us  how.txt
# Article extracted and saved: extracted_articles\blackassign0083_Human Rights Outlook  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0084_How Voice search makes your business a successful business  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0085_How the COVID19 crisis is redefining jobs and services  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0086_How to increase social media engagement for marketers  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0087_Impacts of COVID 19 on Streets Sides Food Stalls  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0088_Coronavirus impact on energy markets  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0089_COVID19 Impact on Hospitality Industrty  blackcoffer insights.txt
# Article extracted and saved: extracted_articles\blackassign0090_key learnings relevant to the coronavirus crisis  Lessons from the past.txt
# Article extracted and saved: extracted_articles\blackassign0091_Estimating the impact of COVID19 on the world of work  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0092_Estimating the impact of COVID19 on the world of work  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0093_Travel and Tourism Outlook  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0094_Gaming Disorder and Effects of Gaming on Health  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0095_What is the repercussion of the environment due to the COVID19 pandemic situation  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0096_Due to the COVID19 the repercussion of the environment  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0097_Impact of COVID19 pandemic on office space and coworking industries  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0098_Contribution of handicrafts Visual Arts  Literature in the Indian economy  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0099_How COVID19 is impacting payment preferences  Blackcoffer Insights.txt
# Article extracted and saved: extracted_articles\blackassign0100_How will COVID19 affect the world of work  Blackcoffer Insights.txt
# Extraction complete.
